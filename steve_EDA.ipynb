# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('Train.csv')

# %%
train.head()
# Out:
#            Tour_ID                   country age_group  \
# 0  tour_id1hffseyw                     ITALY     45-64
# 1  tour_idnacd7zag            UNITED KINGDOM     25-44
# 2  tour_id62vz7e71  UNITED STATES OF AMERICA       65+
# 3  tour_idrc76tzix                    RWANDA     25-44
# 4  tour_idn723m0n9  UNITED STATES OF AMERICA     45-64
#
#                 travel_with  total_female  total_male  \
# 0             With Children           0.0         2.0
# 1               With Spouse           1.0         1.0
# 2               With Spouse           1.0         1.0
# 3  With Spouse and Children           3.0         1.0
# 4                     Alone           0.0         1.0
#
#                           purpose     main_activity  \
# 0  Visiting Friends and Relatives     Beach Tourism
# 1            Leisure and Holidays  Wildlife Tourism
# 2            Leisure and Holidays   Widlife Tourism
# 3            Leisure and Holidays     Beach Tourism
# ...

# %%
train.columns
# Out:
# Index(['Tour_ID', 'country', 'age_group', 'travel_with', 'total_female',
#        'total_male', 'purpose', 'main_activity', 'info_source',
#        'tour_arrangement', 'package_transport_int', 'package_accomodation',
#        'package_food', 'package_transport_tz', 'package_sightseeing',
#        'package_guided_tour', 'package_insurance', 'night_mainland',
#        'night_zanzibar', 'first_trip_tz', 'cost_category'],
#       dtype='object')

# %%
train.dtypes
# Out:
# Tour_ID                   object
# country                   object
# age_group                 object
# travel_with               object
# total_female             float64
# total_male               float64
# purpose                   object
# main_activity             object
# info_source               object
# tour_arrangement          object
# package_transport_int     object
# package_accomodation      object
# package_food              object
# package_transport_tz      object
# package_sightseeing       object
# package_guided_tour       object
# package_insurance         object
# night_mainland             int64
# night_zanzibar             int64
# first_trip_tz             object
# cost_category             object
# dtype: object

# %%
train.cost_category = train.cost_category.astype('category')
train.purpose = train.purpose.astype('category')
train.main_activity = train.main_activity.astype('category')
train.info_source = train.info_source.astype('category')
train.tour_arrangement= train.tour_arrangement.astype('category')
train.age_group = train.age_group.astype('category')
train.travel_with = train.travel_with.astype('category')

# %%
train.dtypes
# Out:
# Tour_ID                    object
# country                    object
# age_group                category
# travel_with              category
# total_female              float64
# total_male                float64
# purpose                  category
# main_activity            category
# info_source              category
# tour_arrangement         category
# package_transport_int      object
# package_accomodation       object
# package_food               object
# package_transport_tz       object
# package_sightseeing        object
# package_guided_tour        object
# package_insurance          object
# night_mainland              int64
# night_zanzibar              int64
# first_trip_tz              object
# cost_category            category
# dtype: object

# %%
train.isnull().sum()
# Out:
# Tour_ID                     0
# country                     0
# age_group                   0
# travel_with              1075
# total_female                2
# total_male                  6
# purpose                     0
# main_activity               0
# info_source                 0
# tour_arrangement            0
# package_transport_int       0
# package_accomodation        0
# package_food                0
# package_transport_tz        0
# package_sightseeing         0
# package_guided_tour         0
# package_insurance           0
# night_mainland              0
# night_zanzibar              0
# first_trip_tz               0
# cost_category               0
# dtype: int64

# %%
train.night_mainland.describe()
# Out:
# count    18506.000000
# mean         9.141576
# std         14.127449
# min          0.000000
# 25%          3.000000
# 50%          6.000000
# 75%         11.000000
# max        365.000000
# Name: night_mainland, dtype: float64

# %%
sns.displot(train.night_mainland, bins=20, kde=False, rug=False)
plt.show()

# %%
train.night_zanzibar.value_counts().sort_index()
# Out:
# 0      11579
# 1        152
# 2        426
# 3        921
# 4       1030
# 5        813
# 6        624
# 7       1533
# 8        284
# 9        171
# 10       244
# 11        78
# 12        87
# 13        62
# 14       216
# 15        64
# 16        19
# 17        24
# 18         9
# 19        13
# 20        33
# 21        26
# 22         8
# 23         6
# 25         4
# 26         1
# 27         4
# 28         8
# 30        13
# 31         1
# 32         1
# 33         3
# 34         1
# 35         6
# 39         2
# 40         2
# 41         3
# 42         2
# 43         1
# 44         2
# 45         1
# 46         1
# 48         1
# 50         1
# 51         2
# 55         1
# 60         6
# 61         1
# 64         1
# 70         1
# 75         1
# 80         1
# 86         1
# 87         1
# 90         4
# 100        1
# 107        1
# 108        1
# 120        2
# 240        1
# Name: night_zanzibar, dtype: int64

# %%
train[train.night_zanzibar == 108]
# Out:
#              Tour_ID         country age_group travel_with  total_female  \
# 429  tour_id7tscf18h  UNITED KINGDOM     45-64       Alone           0.0
#
#      total_male                         purpose     main_activity  \
# 429         1.0  Visiting Friends and Relatives  Cultural Tourism
#
#             info_source tour_arrangement  ... package_accomodation  \
# 429  Friends, relatives      Independent  ...                   No
#
#     package_food package_transport_tz package_sightseeing package_guided_tour  \
# 429           No                   No                  No                  No
#
#     package_insurance night_mainland  night_zanzibar  first_trip_tz  \
# 429                No              0             108             No
#
#     cost_category
# 429   Normal Cost
#
# [1 rows x 21 columns]

# %%
train.dtypes
# Out:
# Tour_ID                    object
# country                    object
# age_group                category
# travel_with              category
# total_female              float64
# total_male                float64
# purpose                  category
# main_activity            category
# info_source              category
# tour_arrangement         category
# package_transport_int      object
# package_accomodation       object
# package_food               object
# package_transport_tz       object
# package_sightseeing        object
# package_guided_tour        object
# package_insurance          object
# night_mainland              int64
# night_zanzibar              int64
# first_trip_tz              object
# cost_category            category
# dtype: object

# %%
sns.countplot(y=train.purpose)
plt.show()

# %%
sns.countplot(y=train.main_activity)
plt.show()

# %%
train['main_activity'].replace('Widlife Tourism', 'Wildlife Tourism', inplace=True)

# %%
sns.countplot(y=train.main_activity)
plt.show()

# %%
sns.countplot(y=train.info_source)
plt.show()

# %%
sns.countplot(y=train.tour_arrangement)
plt.show()

# %%
sns.countplot(y=train.cost_category)
plt.show()

# %%
train.dtypes
# Out:
# Tour_ID                    object
# country                    object
# age_group                category
# travel_with              category
# total_female              float64
# total_male                float64
# purpose                  category
# main_activity            category
# info_source              category
# tour_arrangement         category
# package_transport_int      object
# package_accomodation       object
# package_food               object
# package_transport_tz       object
# package_sightseeing        object
# package_guided_tour        object
# package_insurance          object
# night_mainland              int64
# night_zanzibar              int64
# first_trip_tz              object
# cost_category            category
# dtype: object
